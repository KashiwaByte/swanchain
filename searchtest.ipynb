# %%
from tools import searchapi
from tools.searchapi.tool import Searchapi

search1=Searchapi()
search1.getapi("po1hgL9to8Ytj8vFEZ5HML4c")
search1._search_api_results("中国有多少人")
# Out:
# 成功
# {'search_metadata': {'id': 'search_M6d97LXP4moruzwLk03EOrl8',
#   'status': 'Success',
#   'created_at': '2023-10-16T13:51:27Z',
#   'request_time_taken': 4.95,
#   'parsing_time_taken': 0.17,
#   'total_time_taken': 5.12,
#   'request_url': 'https://www.google.com/search?q=%E4%B8%AD%E5%9B%BD%E6%9C%89%E5%A4%9A%E5%B0%91%E4%BA%BA&oq=%E4%B8%AD%E5%9B%BD%E6%9C%89%E5%A4%9A%E5%B0%91%E4%BA%BA&gl=us&hl=en&ie=UTF-8',
#   'html_url': 'https://www.searchapi.io/api/v1/searches/search_M6d97LXP4moruzwLk03EOrl8.html',
#   'json_url': 'https://www.searchapi.io/api/v1/searches/search_M6d97LXP4moruzwLk03EOrl8'},
#  'search_parameters': {'engine': 'google',
#   'q': '中国有多少人',
#   'device': 'desktop',
#   'google_domain': 'google.com',
#   'hl': 'en',
#   'gl': 'us'},
#  'search_information': {'query_displayed': '中国有多少人',
#   'total_results': 568000000,
#   'time_taken_displayed': 0.42},
#  'answer_box': {'type': 'organic_result', 'title': 'China/Population'},
# ...

# %%
search1.run("中国有多少人")
# Out:
# "China, officially the People's Republic of China, is a country in East Asia. It is the world's second-most populous country with a population exceeding 1.4 billion. China spans the equivalent of five time zones and borders fourteen countries by land, tied with Russia as having the most of any country in the world."
